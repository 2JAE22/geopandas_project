# %%
pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/c3/6c/ea362eef61f05553aaf1a24b3e96b2d0603f5dc71a3bd35688a24ed88843/pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Obtaining dependency information for numpy>=1.20.3 from https://files.pythonhosted.org/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.8 MB 5.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.8 MB 10.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/10.8 MB 11.6 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/10.8 MB 12.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/10.8 MB 16.3 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.8 MB 18.2 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.8 MB 22.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.8 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 31.2 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ---------- ----------------------------- 3.9/14.9 MB 82.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.8/14.9 MB 112.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 81.8 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.24.4 pandas-2.0.3 pytz-2023.3 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/cb/7b/2fb6ab376c78d2e60812ad0bf4b24889309d2aeb543f54efcd586c69907f/geopandas-0.13.2-py3-none-any.whl.metadata
#   Downloading geopandas-0.13.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting fiona>=1.8.19 (from geopandas)
#   Obtaining dependency information for fiona>=1.8.19 from https://files.pythonhosted.org/packages/2b/ea/6f581dbc322f9bd7eeb397ca81444dcd0ba1c2aead5113f017be61de8919/Fiona-1.9.4.post1-cp38-cp38-win_amd64.whl.metadata
#   Downloading Fiona-1.9.4.post1-cp38-cp38-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/50.6 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 50.6/50.6 kB 859.7 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from geopandas) (2.0.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.5.0-cp38-cp38-win_amd64.whl (5.1 MB)
#      ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/5.1 MB 10.2 MB/s eta 0:00:01
#      -------- ------------------------------- 1.1/5.1 MB 13.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 2.1/5.1 MB 16.5 MB/s eta 0:00:01
#      --------------------------- ------------ 3.5/5.1 MB 20.4 MB/s eta 0:00:01
#      ---------------------------------------  5.1/5.1 MB 25.2 MB/s eta 0:00:01
#      ---------------------------------------- 5.1/5.1 MB 23.4 MB/s eta 0:00:00
# Collecting shapely>=1.7.1 (from geopandas)
#   Downloading shapely-2.0.1-cp38-cp38-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      ---------------------------------------- 1.4/1.4 MB 44.5 MB/s eta 0:00:00
# Collecting attrs>=19.2.0 (from fiona>=1.8.19->geopandas)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Collecting certifi (from fiona>=1.8.19->geopandas)
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting click~=8.0 (from fiona>=1.8.19->geopandas)
#   Obtaining dependency information for click~=8.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: importlib-metadata in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from fiona>=1.8.19->geopandas) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from pandas>=1.1.0->geopandas) (1.24.4)
# Requirement already satisfied: colorama in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\ananconda3.2\envs\geo\lib\site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.11.0)
# Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB
win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 91.2 MB/s eta 0:00:00
# Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Downloading kiwisolver-1.4.5-cp38-cp38-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB 3.1 MB/s eta 0:00:00
# Downloading Pillow-10.0.0-cp38-cp38-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 80.7 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.1 importlib-resources-6.0.1 kiwisolver-1.4.5 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
gpd.__version__
# Out:
# '0.13.2'

# %%
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
cities = gpd.read_file(gpd.datasets.get_path("naturalearth_cities"))
cities.head()
# Out:
#            name                    geometry
# 0  Vatican City   POINT (12.45339 41.90328)
# 1    San Marino   POINT (12.44177 43.93610)
# 2         Vaduz    POINT (9.51667 47.13372)
# 3       Lobamba  POINT (31.20000 -26.46667)
# 4    Luxembourg    POINT (6.13000 49.61166)

# %%
# fig, ax = plt.subplots(figsize=(10, 8)) 
ax = countries.plot(column ="continent",legend = True, categorical= True)
ax.set_title("World_Map")
ax.set_axis_off()
plt.show()

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#1인당 GDP 계산
countries.loc[:,"GDP_PER_CAP"] = countries.loc[:,"gdp_md_est"]/countries.loc[:,"pop_est"]*100
countries
#md=million dollars , est = estimation, pop = population_임.
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry  GDP_PER_CAP
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...     0.617561
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...     0.108916
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...     0.150352
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...     4.619471
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...     6.529752
# ..                                                 ...          ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...     0.741183
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...     0.890801
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...     0.441745
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...     1.739747
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...     0.108460
#
# [177 rows x 7 columns]
